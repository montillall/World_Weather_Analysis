# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import Dependencies
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

from citipy import citipy
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Perform an API call with the OpenWeatherMap

# Create counters.
record_count = 1
set_count = 1

# Create an empty list to hold the weather data.
city_data = []
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list, using enumerate() method to loop index and item simultaneously.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = basic_url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Increment record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | arroyo
# Processing Record 5 of Set 1 | svetlogorsk
# Processing Record 6 of Set 1 | buraydah
# Processing Record 7 of Set 1 | ilhabela
# Processing Record 8 of Set 1 | vanimo
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | grand gaube
# Processing Record 11 of Set 1 | berlevag
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | abong mbang
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | weihe
# Processing Record 22 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | alofi
# Processing Record 30 of Set 1 | manaure
# Processing Record 31 of Set 1 | carrboro
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | eureka
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | vestmannaeyjar
# Processing Record 37 of Set 1 | kryvyy rih
# Processing Record 38 of Set 1 | sibolga
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | hamilton
# Processing Record 44 of Set 1 | bonavista
# Processing Record 45 of Set 1 | council bluffs
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | wuhu
# Processing Record 50 of Set 1 | halifax
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | straseni
# Processing Record 3 of Set 2 | ingham
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | kailua
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | khani
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | buy
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | fort saint james
# Processing Record 16 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 17 of Set 2 | makakilo city
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | oistins
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | lagoa
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | sao filipe
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | tambura
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | batemans bay
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | mareeba
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | portland
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | bellary
# Processing Record 40 of Set 2 | mildura
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | noshiro
# Processing Record 43 of Set 2 | salisbury
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | rabo de peixe
# Processing Record 47 of Set 2 | srikakulam
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | urumqi
# Processing Record 50 of Set 2 | lidzbark warminski
# Processing Record 1 of Set 3 | kalmunai
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | loja
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | constitucion
# Processing Record 7 of Set 3 | danao
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | belaya gora
# Processing Record 10 of Set 3 | san juan
# Processing Record 11 of Set 3 | bosaso
# Processing Record 12 of Set 3 | we
# City not found. Skipping...
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | darovskoy
# Processing Record 16 of Set 3 | palmas
# Processing Record 17 of Set 3 | kibre mengist
# Processing Record 18 of Set 3 | cochrane
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | srednekolymsk
# Processing Record 21 of Set 3 | parrsboro
# Processing Record 22 of Set 3 | nago
# Processing Record 23 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 3 | riyadh
# Processing Record 25 of Set 3 | helena
# Processing Record 26 of Set 3 | kiunga
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | colac
# Processing Record 29 of Set 3 | karratha
# Processing Record 30 of Set 3 | deputatskiy
# Processing Record 31 of Set 3 | saint anthony
# Processing Record 32 of Set 3 | isangel
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | poum
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | nochistlan
# Processing Record 38 of Set 3 | harper
# Processing Record 39 of Set 3 | pangai
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | san jeronimo
# Processing Record 42 of Set 3 | shchigry
# Processing Record 43 of Set 3 | havoysund
# Processing Record 44 of Set 3 | tateyama
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | burica
# City not found. Skipping...
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | mendi
# Processing Record 49 of Set 3 | vestmanna
# Processing Record 50 of Set 3 | guerrero negro
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | kutum
# Processing Record 4 of Set 4 | san francisco
# Processing Record 5 of Set 4 | la ferte-bernard
# Processing Record 6 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 4 | marsh harbour
# Processing Record 8 of Set 4 | zambezi
# Processing Record 9 of Set 4 | langxiang
# Processing Record 10 of Set 4 | lavrentiya
# Processing Record 11 of Set 4 | shebunino
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | jardim
# Processing Record 14 of Set 4 | flin flon
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | birao
# Processing Record 17 of Set 4 | kenai
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | bayanday
# Processing Record 20 of Set 4 | hirara
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | erbaa
# Processing Record 24 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | nanga eboko
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | atasu
# Processing Record 31 of Set 4 | rudnyy
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | bilibino
# Processing Record 35 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 4 | robertsport
# Processing Record 37 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 4 | bathsheba
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | altamont
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | yandyki
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 4 | magadan
# Processing Record 47 of Set 4 | angra
# City not found. Skipping...
# Processing Record 48 of Set 4 | tual
# Processing Record 49 of Set 4 | pontianak
# Processing Record 50 of Set 4 | kintinku
# Processing Record 1 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | beringovskiy
# Processing Record 4 of Set 5 | sanchor
# Processing Record 5 of Set 5 | baruun-urt
# Processing Record 6 of Set 5 | matamoros
# Processing Record 7 of Set 5 | santiago
# Processing Record 8 of Set 5 | araouane
# Processing Record 9 of Set 5 | charters towers
# Processing Record 10 of Set 5 | hofn
# Processing Record 11 of Set 5 | ous
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | ahipara
# Processing Record 14 of Set 5 | tsumeb
# Processing Record 15 of Set 5 | laguna
# Processing Record 16 of Set 5 | taltal
# Processing Record 17 of Set 5 | tilichiki
# Processing Record 18 of Set 5 | sao gabriel
# Processing Record 19 of Set 5 | bangassou
# Processing Record 20 of Set 5 | costa rica
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | port hueneme
# Processing Record 25 of Set 5 | jasidih
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | banamba
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | osorno
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | lujan
# Processing Record 33 of Set 5 | riaba
# City not found. Skipping...
# Processing Record 34 of Set 5 | nabire
# Processing Record 35 of Set 5 | varzea da palma
# Processing Record 36 of Set 5 | crawfordsville
# Processing Record 37 of Set 5 | kawalu
# Processing Record 38 of Set 5 | puerto madryn
# Processing Record 39 of Set 5 | panaba
# Processing Record 40 of Set 5 | uyemskiy
# Processing Record 41 of Set 5 | karangasem
# Processing Record 42 of Set 5 | port elizabeth
# Processing Record 43 of Set 5 | vite
# Processing Record 44 of Set 5 | lavumisa
# Processing Record 45 of Set 5 | camabatela
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | tiksi
# Processing Record 48 of Set 5 | shetpe
# Processing Record 49 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | miyako
# Processing Record 2 of Set 6 | puerto carreno
# Processing Record 3 of Set 6 | sambava
# Processing Record 4 of Set 6 | digha
# Processing Record 5 of Set 6 | denpasar
# Processing Record 6 of Set 6 | allonnes
# Processing Record 7 of Set 6 | goderich
# Processing Record 8 of Set 6 | carora
# Processing Record 9 of Set 6 | sergeyevka
# Processing Record 10 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 6 | kandrian
# Processing Record 12 of Set 6 | puerto maldonado
# Processing Record 13 of Set 6 | sola
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | hammerfest
# Processing Record 16 of Set 6 | kayan
# Processing Record 17 of Set 6 | bulawayo
# Processing Record 18 of Set 6 | salalah
# Processing Record 19 of Set 6 | komsomolskiy
# Processing Record 20 of Set 6 | port-gentil
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | ponta do sol
# Processing Record 23 of Set 6 | hay river
# Processing Record 24 of Set 6 | lopatino
# Processing Record 25 of Set 6 | lagunas
# Processing Record 26 of Set 6 | nuevo progreso
# Processing Record 27 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 6 | nizhniy ingash
# Processing Record 29 of Set 6 | kismayo
# Processing Record 30 of Set 6 | liberal
# Processing Record 31 of Set 6 | teacapan
# Processing Record 32 of Set 6 | stornoway
# Processing Record 33 of Set 6 | guaruja
# Processing Record 34 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 6 | viking
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | anadyr
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 6 | mandiana
# Processing Record 41 of Set 6 | vondrozo
# Processing Record 42 of Set 6 | la plata
# Processing Record 43 of Set 6 | huilong
# Processing Record 44 of Set 6 | hualmay
# Processing Record 45 of Set 6 | comodoro rivadavia
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | mount pleasant
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | la ronge
# Processing Record 1 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 7 | cherskiy
# Processing Record 3 of Set 7 | seeboden
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | tomarovka
# Processing Record 6 of Set 7 | port pirie
# Processing Record 7 of Set 7 | lucapa
# Processing Record 8 of Set 7 | norman wells
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | jaisalmer
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | shache
# Processing Record 14 of Set 7 | awjilah
# Processing Record 15 of Set 7 | magway
# Processing Record 16 of Set 7 | yar-sale
# Processing Record 17 of Set 7 | umm lajj
# Processing Record 18 of Set 7 | flinders
# Processing Record 19 of Set 7 | sabzevar
# Processing Record 20 of Set 7 | cayenne
# Processing Record 21 of Set 7 | davila
# Processing Record 22 of Set 7 | emba
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | fort nelson
# Processing Record 25 of Set 7 | bonfim
# Processing Record 26 of Set 7 | alta floresta
# Processing Record 27 of Set 7 | terra nova
# Processing Record 28 of Set 7 | alice springs
# Processing Record 29 of Set 7 | broome
# Processing Record 30 of Set 7 | camacha
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | asfi
# Processing Record 33 of Set 7 | acari
# Processing Record 34 of Set 7 | carbondale
# Processing Record 35 of Set 7 | bundaberg
# Processing Record 36 of Set 7 | surt
# Processing Record 37 of Set 7 | havre-saint-pierre
# Processing Record 38 of Set 7 | rapid valley
# Processing Record 39 of Set 7 | aswan
# Processing Record 40 of Set 7 | namatanai
# Processing Record 41 of Set 7 | nouadhibou
# Processing Record 42 of Set 7 | santa rita
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | amuntai
# Processing Record 45 of Set 7 | jacareacanga
# Processing Record 46 of Set 7 | indianola
# Processing Record 47 of Set 7 | peniche
# Processing Record 48 of Set 7 | rovaniemi
# Processing Record 49 of Set 7 | nouakchott
# Processing Record 50 of Set 7 | mindelo
# Processing Record 1 of Set 8 | sozimskiy
# Processing Record 2 of Set 8 | buckeye
# Processing Record 3 of Set 8 | valente
# Processing Record 4 of Set 8 | bandarbeyla
# Processing Record 5 of Set 8 | launceston
# Processing Record 6 of Set 8 | rioja
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | phalombe
# Processing Record 9 of Set 8 | seminole
# Processing Record 10 of Set 8 | moron
# Processing Record 11 of Set 8 | rusape
# Processing Record 12 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 13 of Set 8 | mogok
# Processing Record 14 of Set 8 | victoria
# Processing Record 15 of Set 8 | necochea
# Processing Record 16 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 17 of Set 8 | japura
# Processing Record 18 of Set 8 | kloulklubed
# Processing Record 19 of Set 8 | hsichih
# City not found. Skipping...
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | vila velha
# Processing Record 22 of Set 8 | narsaq
# Processing Record 23 of Set 8 | klyuchi
# Processing Record 24 of Set 8 | karasburg
# Processing Record 25 of Set 8 | honningsvag
# Processing Record 26 of Set 8 | lamont
# Processing Record 27 of Set 8 | tornio
# Processing Record 28 of Set 8 | fuyang
# Processing Record 29 of Set 8 | rio gallegos
# Processing Record 30 of Set 8 | dibulla
# Processing Record 31 of Set 8 | obidos
# Processing Record 32 of Set 8 | nizwa
# Processing Record 33 of Set 8 | svetlyy
# Processing Record 34 of Set 8 | katherine
# Processing Record 35 of Set 8 | williamsburg
# Processing Record 36 of Set 8 | tiarei
# Processing Record 37 of Set 8 | verkhnevilyuysk
# Processing Record 38 of Set 8 | evensk
# Processing Record 39 of Set 8 | spas-demensk
# Processing Record 40 of Set 8 | russell
# Processing Record 41 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 8 | barranca
# Processing Record 43 of Set 8 | vung tau
# Processing Record 44 of Set 8 | los llanos de aridane
# Processing Record 45 of Set 8 | shasta lake
# Processing Record 46 of Set 8 | lata
# Processing Record 47 of Set 8 | junction city
# Processing Record 48 of Set 8 | goundam
# Processing Record 49 of Set 8 | caravelas
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | jieshi
# Processing Record 2 of Set 9 | banepa
# Processing Record 3 of Set 9 | joshimath
# Processing Record 4 of Set 9 | severo-yeniseyskiy
# Processing Record 5 of Set 9 | ulladulla
# Processing Record 6 of Set 9 | andenes
# Processing Record 7 of Set 9 | gedo
# Processing Record 8 of Set 9 | wenatchee
# Processing Record 9 of Set 9 | savelugu
# Processing Record 10 of Set 9 | acapulco
# Processing Record 11 of Set 9 | fare
# Processing Record 12 of Set 9 | altay
# Processing Record 13 of Set 9 | kang
# Processing Record 14 of Set 9 | shitkino
# Processing Record 15 of Set 9 | anandnagar
# Processing Record 16 of Set 9 | pec
# Processing Record 17 of Set 9 | shatki
# Processing Record 18 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 9 | aripuana
# Processing Record 20 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 9 | berdigestyakh
# Processing Record 22 of Set 9 | smithers
# Processing Record 23 of Set 9 | coari
# Processing Record 24 of Set 9 | marawi
# Processing Record 25 of Set 9 | hasaki
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | muisne
# Processing Record 28 of Set 9 | saravena
# Processing Record 29 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 9 | coihaique
# Processing Record 31 of Set 9 | saint john
# Processing Record 32 of Set 9 | san andres
# Processing Record 33 of Set 9 | garissa
# Processing Record 34 of Set 9 | mathbaria
# Processing Record 35 of Set 9 | awbari
# Processing Record 36 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | dubovka
# Processing Record 39 of Set 9 | khandbari
# Processing Record 40 of Set 9 | eyl
# Processing Record 41 of Set 9 | saraland
# Processing Record 42 of Set 9 | madison
# Processing Record 43 of Set 9 | havre
# Processing Record 44 of Set 9 | porto novo
# Processing Record 45 of Set 9 | corinto
# Processing Record 46 of Set 9 | havelock
# Processing Record 47 of Set 9 | jalu
# Processing Record 48 of Set 9 | dudinka
# Processing Record 49 of Set 9 | alghero
# Processing Record 50 of Set 9 | minab
# Processing Record 1 of Set 10 | pierre
# Processing Record 2 of Set 10 | mahebourg
# Processing Record 3 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 4 of Set 10 | wanning
# Processing Record 5 of Set 10 | vostok
# Processing Record 6 of Set 10 | kodinsk
# Processing Record 7 of Set 10 | praia da vitoria
# Processing Record 8 of Set 10 | chimbote
# Processing Record 9 of Set 10 | talnakh
# Processing Record 10 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 10 | antequera
# Processing Record 12 of Set 10 | sarangani
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | cap malheureux
# Processing Record 15 of Set 10 | atyrau
# Processing Record 16 of Set 10 | syracuse
# Processing Record 17 of Set 10 | sawakin
# Processing Record 18 of Set 10 | epiniana
# Processing Record 19 of Set 10 | kaoma
# Processing Record 20 of Set 10 | dakar
# Processing Record 21 of Set 10 | hudson bay
# Processing Record 22 of Set 10 | pevek
# Processing Record 23 of Set 10 | tynda
# Processing Record 24 of Set 10 | mawlaik
# Processing Record 25 of Set 10 | gloversville
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | north bend
# Processing Record 28 of Set 10 | sokoni
# Processing Record 29 of Set 10 | ohrid
# Processing Record 30 of Set 10 | vanderhoof
# Processing Record 31 of Set 10 | sur
# Processing Record 32 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 33 of Set 10 | dahanu
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | mandalgovi
# Processing Record 36 of Set 10 | marrakesh
# Processing Record 37 of Set 10 | nizhniy tsasuchey
# Processing Record 38 of Set 10 | henties bay
# Processing Record 39 of Set 10 | cabimas
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | birin
# Processing Record 42 of Set 10 | hede
# Processing Record 43 of Set 10 | goldsboro
# Processing Record 44 of Set 10 | radomsko
# Processing Record 45 of Set 10 | benguela
# Processing Record 46 of Set 10 | katobu
# Processing Record 47 of Set 10 | road town
# Processing Record 48 of Set 10 | lekoni
# Processing Record 49 of Set 10 | zeya
# Processing Record 50 of Set 10 | nayoro
# Processing Record 1 of Set 11 | rostaq
# City not found. Skipping...
# Processing Record 2 of Set 11 | howard springs
# Processing Record 3 of Set 11 | devarkonda
# Processing Record 4 of Set 11 | lotofaga
# Processing Record 5 of Set 11 | traralgon
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | buchanan
# Processing Record 8 of Set 11 | menongue
# Processing Record 9 of Set 11 | emmett
# Processing Record 10 of Set 11 | dodoma
# Processing Record 11 of Set 11 | steinbach
# Processing Record 12 of Set 11 | egvekinot
# Processing Record 13 of Set 11 | bucak
# Processing Record 14 of Set 11 | maneadero
# Processing Record 15 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | batagay-alyta
# Processing Record 17 of Set 11 | cabedelo
# Processing Record 18 of Set 11 | qaqortoq
# Processing Record 19 of Set 11 | mormugao
# Processing Record 20 of Set 11 | general roca
# Processing Record 21 of Set 11 | turmalina
# Processing Record 22 of Set 11 | kalianget
# Processing Record 23 of Set 11 | muzhi
# Processing Record 24 of Set 11 | tessalit
# Processing Record 25 of Set 11 | morondava
# Processing Record 26 of Set 11 | avera
# Processing Record 27 of Set 11 | olafsvik
# Processing Record 28 of Set 11 | haverfordwest
# Processing Record 29 of Set 11 | san policarpo
# Processing Record 30 of Set 11 | quelimane
# Processing Record 31 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 11 | chany
# Processing Record 33 of Set 11 | linkoping
# Processing Record 34 of Set 11 | lapithos
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | alanya
# Processing Record 37 of Set 11 | goundi
# Processing Record 38 of Set 11 | tayu
# Processing Record 39 of Set 11 | san ramon
# Processing Record 40 of Set 11 | chipata
# Processing Record 41 of Set 11 | oranjestad
# Processing Record 42 of Set 11 | khorixas
# Processing Record 43 of Set 11 | puerto escondido
# Processing Record 44 of Set 11 | magdalena
# Processing Record 45 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 11 | la libertad
# Processing Record 47 of Set 11 | kumluca
# Processing Record 48 of Set 11 | santa maria
# Processing Record 49 of Set 11 | changuinola
# Processing Record 50 of Set 11 | san carlos de bariloche
# Processing Record 1 of Set 12 | san pedro de macoris
# Processing Record 2 of Set 12 | san roque
# Processing Record 3 of Set 12 | richards bay
# Processing Record 4 of Set 12 | port-cartier
# Processing Record 5 of Set 12 | calvia
# Processing Record 6 of Set 12 | viedma
# Processing Record 7 of Set 12 | safranbolu
# Processing Record 8 of Set 12 | doha
# Processing Record 9 of Set 12 | torbay
# Processing Record 10 of Set 12 | sinnamary
# Processing Record 11 of Set 12 | atar
# Processing Record 12 of Set 12 | sioux lookout
# Processing Record 13 of Set 12 | arbroath
# Processing Record 14 of Set 12 | zhigansk
# Processing Record 15 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 12 | wilmington
# Processing Record 17 of Set 12 | agua branca
# Processing Record 18 of Set 12 | lompoc
# Processing Record 19 of Set 12 | farmington
# Processing Record 20 of Set 12 | juazeiro
# Processing Record 21 of Set 12 | general pico
# Processing Record 22 of Set 12 | ahuimanu
# Processing Record 23 of Set 12 | puli
# Processing Record 24 of Set 12 | am timan
# Processing Record 25 of Set 12 | udachnyy
# Processing Record 26 of Set 12 | thohoyandou
# Processing Record 27 of Set 12 | christchurch
# Processing Record 28 of Set 12 | antalaha
# Processing Record 29 of Set 12 | miles city
# Processing Record 30 of Set 12 | candolim
# Processing Record 31 of Set 12 | gat
# Processing Record 32 of Set 12 | laramie
# Processing Record 33 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 34 of Set 12 | bonthe
# Processing Record 35 of Set 12 | bam
# Processing Record 36 of Set 12 | ust-kuyga
# Processing Record 37 of Set 12 | panjab
# Processing Record 38 of Set 12 | lincoln
# Processing Record 39 of Set 12 | magadi
# Processing Record 40 of Set 12 | brainerd
# Processing Record 41 of Set 12 | la primavera
# Processing Record 42 of Set 12 | goryachegorsk
# Processing Record 43 of Set 12 | bone
# Processing Record 44 of Set 12 | dawson creek
# Processing Record 45 of Set 12 | fort-shevchenko
# Processing Record 46 of Set 12 | isilkul
# Processing Record 47 of Set 12 | inverness
# Processing Record 48 of Set 12 | loandjili
# Processing Record 49 of Set 12 | waingapu
# Processing Record 50 of Set 12 | scottsbluff
# Processing Record 1 of Set 13 | sao joao evangelista
# Processing Record 2 of Set 13 | aliwal north
# Processing Record 3 of Set 13 | waipawa
# Processing Record 4 of Set 13 | tinaquillo
# Processing Record 5 of Set 13 | tsogni
# Processing Record 6 of Set 13 | vanavara
# Processing Record 7 of Set 13 | turukhansk
# Processing Record 8 of Set 13 | sembe
# Processing Record 9 of Set 13 | marienburg
# Processing Record 10 of Set 13 | kitgum
# Processing Record 11 of Set 13 | north myrtle beach
# Processing Record 12 of Set 13 | springbok
# Processing Record 13 of Set 13 | gogrial
# Processing Record 14 of Set 13 | korla
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | tura
# Processing Record 17 of Set 13 | olga
# Processing Record 18 of Set 13 | medicine hat
# Processing Record 19 of Set 13 | ilo
# Processing Record 20 of Set 13 | waterloo
# Processing Record 21 of Set 13 | sao joao da barra
# Processing Record 22 of Set 13 | santa marta
# Processing Record 23 of Set 13 | dwarka
# Processing Record 24 of Set 13 | anjiang
# Processing Record 25 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 26 of Set 13 | biltine
# Processing Record 27 of Set 13 | xai-xai
# Processing Record 28 of Set 13 | mayahi
# Processing Record 29 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 13 | inuvik
# Processing Record 31 of Set 13 | tecoanapa
# Processing Record 32 of Set 13 | san carlos
# Processing Record 33 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 13 | mehamn
# Processing Record 35 of Set 13 | sangmelima
# Processing Record 36 of Set 13 | aksarka
# Processing Record 37 of Set 13 | kargasok
# Processing Record 38 of Set 13 | malatya
# Processing Record 39 of Set 13 | sechura
# Processing Record 40 of Set 13 | sorrento
# Processing Record 41 of Set 13 | brae
# Processing Record 42 of Set 13 | kahului
# Processing Record 43 of Set 13 | boyolangu
# Processing Record 44 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 13 | anloga
# Processing Record 46 of Set 13 | kaolinovo
# Processing Record 47 of Set 13 | bubaque
# Processing Record 48 of Set 13 | redmond
# Processing Record 49 of Set 13 | olinda
# Processing Record 50 of Set 13 | nishihara
# Processing Record 1 of Set 14 | nichinan
# Processing Record 2 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 14 | qandala
# Processing Record 4 of Set 14 | connersville
# Processing Record 5 of Set 14 | oxapampa
# Processing Record 6 of Set 14 | badvel
# Processing Record 7 of Set 14 | reconquista
# Processing Record 8 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 14 | auki
# Processing Record 10 of Set 14 | belluno
# Processing Record 11 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 14 | port shepstone
# Processing Record 13 of Set 14 | tara
# Processing Record 14 of Set 14 | sidi ali
# Processing Record 15 of Set 14 | amatlan
# City not found. Skipping...
# Processing Record 16 of Set 14 | panuco
# Processing Record 17 of Set 14 | solsona
# Processing Record 18 of Set 14 | senador jose porfirio
# Processing Record 19 of Set 14 | bukama
# Processing Record 20 of Set 14 | san ignacio
# Processing Record 21 of Set 14 | klaksvik
# Processing Record 22 of Set 14 | zabaykalsk
# Processing Record 23 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 24 of Set 14 | choa saidan shah
# Processing Record 25 of Set 14 | abu samrah
# Processing Record 26 of Set 14 | beyneu
# Processing Record 27 of Set 14 | krasnoselkup
# Processing Record 28 of Set 14 | nyurba
# Processing Record 29 of Set 14 | bay roberts
# Processing Record 30 of Set 14 | wichita falls
# Processing Record 31 of Set 14 | merauke
# Processing Record 32 of Set 14 | mahibadhoo
# Processing Record 33 of Set 14 | bergen
# Processing Record 34 of Set 14 | nyagan
# Processing Record 35 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 14 | cururupu
# Processing Record 37 of Set 14 | skegness
# Processing Record 38 of Set 14 | manzhouli
# Processing Record 39 of Set 14 | hambantota
# Processing Record 40 of Set 14 | ha tinh
# Processing Record 41 of Set 14 | ust-nera
# Processing Record 42 of Set 14 | gusau
# Processing Record 43 of Set 14 | pekalongan
# Processing Record 44 of Set 14 | nurota
# Processing Record 45 of Set 14 | yanam
# Processing Record 46 of Set 14 | ayan
# Processing Record 47 of Set 14 | mitu
# Processing Record 48 of Set 14 | emerald
# Processing Record 49 of Set 14 | blackwater
# Processing Record 50 of Set 14 | samarai
# Processing Record 1 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | vedaranniyam
# City not found. Skipping...
# Processing Record 3 of Set 15 | sabang
# Processing Record 4 of Set 15 | kabalo
# Processing Record 5 of Set 15 | bagado
# Processing Record 6 of Set 15 | petrovsk
# Processing Record 7 of Set 15 | humberto de campos
# Processing Record 8 of Set 15 | broken hill
# Processing Record 9 of Set 15 | marystown
# Processing Record 10 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 15 | mahates
# Processing Record 12 of Set 15 | chumikan
# Processing Record 13 of Set 15 | garowe
# Processing Record 14 of Set 15 | sept-iles
# Processing Record 15 of Set 15 | yenagoa
# Processing Record 16 of Set 15 | fukue
# Processing Record 17 of Set 15 | maloh
# Processing Record 18 of Set 15 | wa
# City not found. Skipping...
# Processing Record 19 of Set 15 | mount gambier
# Processing Record 20 of Set 15 | ajaccio
# Processing Record 21 of Set 15 | gushikawa
# Processing Record 22 of Set 15 | tarko-sale
# Processing Record 23 of Set 15 | cockburn town
# Processing Record 24 of Set 15 | zhuanghe
# Processing Record 25 of Set 15 | sidhpura
# Processing Record 26 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 15 | mashhad
# Processing Record 28 of Set 15 | lianzhou
# Processing Record 29 of Set 15 | san lucas
# Processing Record 30 of Set 15 | kampene
# Processing Record 31 of Set 15 | kurchum
# Processing Record 32 of Set 15 | searcy
# Processing Record 33 of Set 15 | edd
# Processing Record 34 of Set 15 | kichmengskiy gorodok
# Processing Record 35 of Set 15 | cam ranh
# Processing Record 36 of Set 15 | khoy
# Processing Record 37 of Set 15 | najran
# Processing Record 38 of Set 15 | chernyshevskiy
# Processing Record 39 of Set 15 | impfondo
# Processing Record 40 of Set 15 | piacabucu
# Processing Record 41 of Set 15 | goleta
# Processing Record 42 of Set 15 | minden
# Processing Record 43 of Set 15 | butterworth
# Processing Record 44 of Set 15 | kagoro
# Processing Record 45 of Set 15 | mbala
# Processing Record 46 of Set 15 | naze
# Processing Record 47 of Set 15 | zhanaozen
# Processing Record 48 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 15 | ixtapa
# Processing Record 50 of Set 15 | half moon bay
# Processing Record 1 of Set 16 | toora-khem
# Processing Record 2 of Set 16 | lerwick
# Processing Record 3 of Set 16 | mahad
# Processing Record 4 of Set 16 | maragogi
# Processing Record 5 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 16 | puerto el triunfo
# Processing Record 7 of Set 16 | blagodarnyy
# Processing Record 8 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 16 | khandyga
# Processing Record 11 of Set 16 | nacala
# Processing Record 12 of Set 16 | xingcheng
# Processing Record 13 of Set 16 | vila
# Processing Record 14 of Set 16 | bukachacha
# Processing Record 15 of Set 16 | mezen
# Processing Record 16 of Set 16 | tinskoy
# Processing Record 17 of Set 16 | naryan-mar
# Processing Record 18 of Set 16 | skjervoy
# Processing Record 19 of Set 16 | axim
# Processing Record 20 of Set 16 | kyren
# Processing Record 21 of Set 16 | carbonia
# Processing Record 22 of Set 16 | ndola
# Processing Record 23 of Set 16 | nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 710

# %%
# Add the data to a new DataFrame..
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Longyearbyen      SJ  78.2186   15.6401     42.64        70          75
# 1   Clyde River      CA  70.4692  -68.5914     35.83        80          20
# 2     Busselton      AU -33.6500  115.3333     55.83        72          97
# 3        Arroyo      ES  41.6096   -4.7969     87.84        30          75
# 4   Svetlogorsk      BY  52.6333   29.7333     57.40        87         100
# 5      Buraydah      SA  26.3260   43.9750    100.85        12           0
# 6      Ilhabela      BR -23.7781  -45.3581     76.91        57           2
# 7        Vanimo      PG  -2.6741  141.3028     76.51        88          27
# 8        Dikson      RU  73.5069   80.5464     30.11        95          48
# 9   Grand Gaube      MU -20.0064   57.6608     69.39        77           1
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1       36.82          few clouds
# 2       22.77     overcast clouds
# 3       13.80        thunderstorm
# 4        3.85     overcast clouds
# 5        5.23           clear sky
# 6        4.00           clear sky
# 7        3.71    scattered clouds
# 8       14.18    scattered clouds
# 9        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Results/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
